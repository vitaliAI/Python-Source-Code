# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import numpy as np
x = np.linspace(0,5,11)
y = x**2

# %%
x
# Out:
# array([ 0. ,  0.5,  1. ,  1.5,  2. ,  2.5,  3. ,  3.5,  4. ,  4.5,  5. ])

# %%
y
# Out:
# array([  0.  ,   0.25,   1.  ,   2.25,   4.  ,   6.25,   9.  ,  12.25,
#         16.  ,  20.25,  25.  ])

# %%
# Functional
plt.plot(x,y,'r-')
plt.xlabel('X Label')
plt.ylabel('Y Label')
plt.title('Title')

# %%
plt.subplot(1,2,1)
plt.plot(x,y,'r')

plt.subplot(1,2,2)
plt.plot(y,x,'b')

# %%
# Object Oriented Method

fig = plt.figure()

axes = fig.add_axes([0.1,0.1,0.8,0.8])

axes.plot(x,y)
axes.set_xlabel('X Label')
axes.set_ylabel('Y Label')
axes.set_title('Set Title')

# %%
fig = plt.figure()

axes1 = fig.add_axes([0.1,0.1,0.8,0.8])

axes2 = fig.add_axes([0.2,0.5,0.4,0.2])

axes1.plot(x,y, 'r-')

axes2.plot(y,x)
axes2.set_title('SMALLER PLOT')

# %%
fig,axes = plt.subplots(nrows=1,ncols=2)

axes[0].plot(x,y)
axes[0].set_title('Plot One')
axes[1].plot(y,x)

# %% [markdown]
# ## Figure Size and DPI

# %%
fig = plt.figure(figsize=(8,2))

ax = fig.add_axes([0,0,1,1])
ax.plot(x,y)

# %%
fig,axes = plt.subplots(nrows=2,ncols=1,figsize=(8,2))
axes[0].plot(x,y)
axes[1].plot(y,x)
plt.tight_layout()

# %%
# save a figure

fig

# %%
fig.savefig('my_picture2.png', dpi=200)

# %% [markdown]
# ## Plot Appearance

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1]) 
ax.plot(x,y,color='#1F8C90', linewidth=13, alpha=0.5) # RGB Hex Code

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1]) 
ax.plot(x,y,color='#1F8C90', linewidth=1, linestyle='--') # RGB Hex Code

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1]) 
ax.plot(x,y,color='#1F8C90', linewidth=1, marker='1', markersize=20, linestyle='steps') # RGB Hex Code

# %%
len(x)
# Out:
# 11

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1]) 
ax.plot(x,y,color='#1F8C90', linewidth=1, alpha=0.8, marker='o') # RGB Hex Code
